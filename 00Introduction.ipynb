# %% [markdown]
# <a href="https://colab.research.google.com/github/MUISHA/ButEntreprise/blob/master/00Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # What kind of data does pandas handle?

# %%
df = pd.DataFrame(

                  {
                      "Name":["Braund, Mr. Owen Harris","Allen, Mr. William Henry","Bonnell, Miss. Elizabeth",],
                      "Age":[22,35,58],
                      "Sex":["Mal","Female","Female"],
                  }
)
df.tail(2)
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22     Mal
# 1  Allen, Mr. William Henry   35  Female
# 2  Bonnell, Miss. Elizabeth   58  Female

# %% [markdown]
# I’m just interested in working with the data in the column Age

# %%
df.Age
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
data = [22,35,58]
ages = pd.Series(data, name = "Age")

# %% [markdown]
# Vérifié le type de donnée dans une column

# %%
ages.dtypes
# Out:
# dtype('int64')

# %%
df["Age"].max()
# Out:
# 58

# %%
ages.max()
# Out:
# 58

# %% [markdown]
# I’m interested in some basic statistics of the numerical data of my data table

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %% [markdown]
# REMEMBER
# Import the package, aka import pandas as pd
#
# A table of data is stored as a pandas DataFrame
#
# Each column in a DataFrame is a Series
#
# You can do things by applying a method to a DataFrame or Series

# %% [markdown]
# # How do I read and write tabular data?

# %%
import pandas as pd
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7ffc9e1-6e4b-4552-bd43-43c1cb3f1ca9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7ffc9e1-6e4b-4552-bd43-43c1cb3f1ca9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# I want to analyze the Titanic passenger data, available as a CSV file.

# %%
titanic = pd.read_csv("titanic.csv")

# %% [markdown]
# To see the first N rows of a DataFrame, use the head() method with the required number of rows (in this case 8) as argument.

# %%
titanic.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %% [markdown]
# A check on how pandas interpreted each of the column data types can be done by requesting the pandas dtypes attribute:

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# I’m interested in a technical summary of a DataFrame

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Voir le no manquante

# %%
titanic["Age"].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# Pour voir le donnees manquante

# %%
titanic["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# How do I select a subset of a DataFrame?

# %%
sexe = titanic["Sex"]
sexe.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %% [markdown]
# Type dans la base de donnée

# %%
type(titanic["Sex"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# And have a look at the shape of the output:

# %%
titanic.shape
# Out:
# (891, 12)

# %%
age_sexe = titanic[["Age","Sex"]]
age_sexe
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(age_sexe)
# Out:
# pandas.core.frame.DataFrame

# %%
age_sexe.shape
# Out:
# (891, 2)

# %% [markdown]
# I’m interested in the passengers older than 35 years.

# %%
age_plus = titanic[titanic['Age']>35]

# %%
age_plus.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
sex_mal =titanic[titanic["Age"]<25]
sex_mal.shape
# Out:
# (278, 12)

# %% [markdown]
# 1ère Façon : Filtre de donnée dans une colonne par rapport au donnée qui sont dans une colonne

# %%
Pclasse1 = titanic[titanic['Pclass'].isin([2,3])]
Pclasse1.shape
# Out:
# (675, 12)

# %% [markdown]
# 2ème Façon : Filtre de donnée dans une colonne par rapport au donnée qui sont dans une colonne

# %% [markdown]
# I want to work with passenger data for which the age is known.

# %%
Pclasse2 = titanic[(titanic["Pclass"]==2)|(titanic["Pclass"]==3)]
Pclasse2.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
age_no_na = titanic[titanic['Age'].notna()]
age_no_na.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# How do I select specific rows and columns from a DataFrame?

# %%
age_plus = titanic.loc[titanic["Age"]< 18, "Name"]
age_plus.shape
# Out:
# (113,)

# %% [markdown]
# Mettre en jour l'Index dans la base de donnée

# %%
titanic.set_index("PassengerId").head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12f49f21-06f1-44ec-8fa5-9d9cb34426e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12f49f21-06f1-44ec-8fa5-9d9cb34426e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
titanic = pd.read_csv("titanic.csv")

# %%
# titanic.set_index("PassengerId")

# %%
titanic
